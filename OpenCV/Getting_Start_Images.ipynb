# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from zipfile import ZipFile
from urllib.request import urlretrieve

from IPython.display import Image

# %matplotlib inline

# %% [markdown]
# ### Download Assets

# %%
def dowload_and_unzip(url, save_path):
    print(f"Downloading and extracting assests...")

    #Temporary locate to save zip file  
    urlretrieve(url, save_path)

    try:

        with ZipFile(save_path) as Z:
            #Extract ZIP File  contents in the same directory
            Z.extractall(os.path.split(save_path)[0])
            print("Done")
    except Exception as e:
        print(f"\n Invalid File. {e}")

# %%
URL = r"https://www.dropbox.com/s/qhhlqcica1nvtaw/opencv_bootcamp_assets_NB1.zip?dl=1"

asset_zip_path = os.path.join(os.getcwd(), f"opencv_bootcamp_assets_NB1.zip")

if not os.path.exists(asset_zip_path):
    dowload_and_unzip(URL, asset_zip_path)

# %%
Image(filename="checkerboard_18x18.png")

# %%
Image(filename="checkerboard_84x84.jpg")

# %%
# Reading images as gray scale
cb_image = cv2.imread("checkerboard_18x18.png")
print(cb_image)

# %%
#Image Atributes

# Hight, Width (x,y)

print(cb_image.shape)

#Type
print(cb_image.dtype)
# Out:
# (18, 18, 3)
# uint8

# %%
#Visualizing using matplot
plt.imshow(cb_image, cmap="gray")

# %%
cb_img_fuzzy = cv2.imread("checkerboard_fuzzy_18x18.jpg", 0)

print(cb_img_fuzzy)

plt.imshow(cb_img_fuzzy, cmap="gray")
# Out:
# [[  0   0  15  20   1 134 233 253 253 253 255 229 130   1  29   2   0   0]
#  [  0   1   5  18   0 137 232 255 254 247 255 228 129   0  24   2   0   0]
#  [  7   5   2  28   2 139 230 254 255 249 255 226 128   0  27   3   2   2]
#  [ 25  27  28  38   0 129 236 255 253 249 251 227 129   0  36  27  27  27]
#  [  2   0   0   4   2 130 239 254 254 254 255 230 126   0   4   2   0   0]
#  [132 129 131 124 121 163 211 226 227 225 226 203 164 125 125 129 131 131]
#  [234 227 230 229 232 205 151 115 125 124 117 156 205 232 229 225 228 228]
#  [254 255 255 251 255 222 102   1   0   0   0 120 225 255 254 255 255 255]
#  [254 255 254 255 253 225 104   0  50  46   0 120 233 254 247 253 251 253]
#  [252 250 250 253 254 223 105   2  45  50   0 127 223 255 251 255 251 253]
#  [254 255 255 252 255 226 104   0   1   1   0 120 229 255 255 254 255 255]
#  [233 235 231 233 234 207 142 106 108 102 108 146 207 235 237 232 231 231]
# ...

# %%
Image(filename="coca-cola-logo.png")

# %%
coke_image = cv2.imread("coca-cola-logo.png", 1)

print(coke_image.dtype)

print(coke_image.shape)
# Out:
# uint8
# (700, 700, 3)

# %%
plt.imshow(coke_image)

# %%
reversed_coke_img = coke_image[:,:, ::-1]

plt.imshow(reversed_coke_img)

# %%
img = cv2.imread("New_Zealand_Lake.jpg", cv2.IMREAD_COLOR) # IMREAD_COLOR = 1 
# Spliting the different colors from original image
b, g, r = cv2.split(img)

plt.figure(figsize=[20,5])

plt.subplot(141);plt.imshow(r, cmap="gray");plt.title("Red Channel")
plt.subplot(142);plt.imshow(g, cmap="gray");plt.title("Green Channel")
plt.subplot(143);plt.imshow(b, cmap="gray");plt.title("Blue Channel")

# Merging the colors to  
imgMerged = cv2.merge((b, g, r))

plt.subplot(144);plt.imshow(img[:, :, ::-1]);plt.title("Merged Output")
# Out:
# Text(0.5, 1.0, 'Merged Output')

# %%
#cvtColot Converse color without use [:, :, ::-1]
img_rbg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rbg)

# %%
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

h,s,v = cv2.split(img_hsv)

plt.figure(figsize=[20,5])

plt.subplot(141);plt.imshow(h, cmap="gray");plt.title("H Channel")
plt.subplot(142);plt.imshow(s, cmap="gray");plt.title("S Channel")
plt.subplot(143);plt.imshow(v, cmap="gray");plt.title("V Channel")
plt.subplot(144);plt.imshow(img_rbg);plt.title("Original ")
# Out:
# Text(0.5, 1.0, 'Original ')

# %%
h_new = h + 10
img_NZ_merged = cv2.merge((h_new, s, v))
img_rbg = cv2.cvtColor(img_NZ_merged, cv2.COLOR_HSV2RGB)

plt.figure(figsize=[20, 5])
plt.subplot(141);plt.imshow(h, cmap="gray");plt.title("H Channel")
plt.subplot(142);plt.imshow(s, cmap="gray");plt.title("S Channel")
plt.subplot(143);plt.imshow(v, cmap="gray");plt.title("V Channel")
plt.subplot(144);plt.imshow(img_rbg);plt.title("Original")
# Out:
# Text(0.5, 1.0, 'Original')

# %%
cv2.imwrite("New_Zealand_Lake_Saved.jpg", img_rbg)

Image(filename="New_Zealand_Lake_Saved.jpg")

# %%
img_saved = cv2.imread("New_Zealand_Lake_Saved.jpg", cv2.IMREAD_COLOR)

print(img_saved.shape)

print(img_saved.dtype)

cv2.imwrite("New_Zealand_Lake_Saved.jpg", img)
# Out:
# (600, 840, 3)
# uint8
# True
